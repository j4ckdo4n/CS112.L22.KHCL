# %%
def QuickSelect(left, right, a, k):
  if (left == right):
    return a[left]
 
  #index = Partition(a, left, right)
  if(left < right):
    index = left -1
    for j in range(left, right):
      if (a[j] >= a[right]):
        index += 1
        a[index], a[j] = a[j], a[index]
 
    a[index + 1], a[right] = a[right], a[index + 1]
    index += 1
 
    if (k == index):
      return a[k]
    if (k < index):
      return QuickSelect(left, index-1, a, k)
    return QuickSelect(index+1, right, a, k)  
def kth_element_qs_Quang(arr, k):
  return QuickSelect(0,len(arr)-1,arr, k-1)

# %%
def kth_element_sort(arr, k):
  arr.sort()
  return arr[len(arr)-k]

# %%
for j in range(1, 40):
  a=[i for i in range(2**j)]
  import random
  random.shuffle(a)
  k = random.randint(0, len(a)-1)
  #print(a[:])
  import cProfile
  print("Kich thuoc mang dang la ", len(a), " k = ", k)
  #cProfile.run("kth_element_sort(a[:], k)")
  #print(a[:])
  cProfile.run("kth_element_qs_Quang(a[:], k)")
# Out:
# Kich thuoc mang dang la  2  k =  1
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  4  k =  1
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  8  k =  1
#          8 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       3/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  16  k =  5
#          10 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       5/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  32  k =  28
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  64  k =  6
#          10 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       5/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  128  k =  127
#          12 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       7/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  256  k =  185
#          15 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      10/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  512  k =  213
#          15 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      10/1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.000    0.000 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  1024  k =  884
#          20 function calls (6 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      15/1    0.001    0.000    0.001    0.001 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.001    0.001 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  2048  k =  1226
#          24 function calls (6 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      19/1    0.001    0.000    0.001    0.001 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.001    0.001 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  4096  k =  3248
#          23 function calls (6 primitive calls) in 0.003 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      18/1    0.003    0.000    0.003    0.003 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.003    0.003 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.003    0.003 <string>:1(<module>)
#         1    0.000    0.000    0.003    0.003 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  8192  k =  6534
#          19 function calls (6 primitive calls) in 0.004 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      14/1    0.004    0.000    0.004    0.004 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.004    0.004 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  16384  k =  15558
#          24 function calls (6 primitive calls) in 0.007 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      19/1    0.007    0.000    0.007    0.007 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.007    0.007 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.000    0.000    0.007    0.007 <string>:1(<module>)
#         1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  32768  k =  26293
#          25 function calls (6 primitive calls) in 0.022 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      20/1    0.022    0.001    0.022    0.022 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.022    0.022 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.001    0.001    0.022    0.022 <string>:1(<module>)
#         1    0.000    0.000    0.022    0.022 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  65536  k =  42604
#          28 function calls (6 primitive calls) in 0.027 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      23/1    0.026    0.001    0.026    0.026 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.026    0.026 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.001    0.001    0.027    0.027 <string>:1(<module>)
#         1    0.000    0.000    0.027    0.027 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  131072  k =  54336
#          33 function calls (6 primitive calls) in 0.112 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      28/1    0.109    0.004    0.109    0.109 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.109    0.109 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.003    0.003    0.112    0.112 <string>:1(<module>)
#         1    0.000    0.000    0.112    0.112 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  262144  k =  153278
#          31 function calls (6 primitive calls) in 0.552 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      26/1    0.544    0.021    0.544    0.544 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.545    0.545 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.007    0.007    0.552    0.552 <string>:1(<module>)
#         1    0.000    0.000    0.552    0.552 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  524288  k =  26950
#          26 function calls (6 primitive calls) in 0.177 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      21/1    0.153    0.007    0.153    0.153 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.153    0.153 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.024    0.024    0.177    0.177 <string>:1(<module>)
#         1    0.000    0.000    0.177    0.177 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  1048576  k =  830237
#          30 function calls (6 primitive calls) in 0.643 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      25/1    0.593    0.024    0.593    0.593 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    0.593    0.593 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.050    0.050    0.643    0.643 <string>:1(<module>)
#         1    0.000    0.000    0.643    0.643 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  2097152  k =  1660612
#          37 function calls (6 primitive calls) in 3.042 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      32/1    2.928    0.092    2.928    2.928 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    2.928    2.928 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.114    0.114    3.042    3.042 <string>:1(<module>)
#         1    0.000    0.000    3.042    3.042 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  4194304  k =  1956008
#          29 function calls (6 primitive calls) in 5.125 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      24/1    4.850    0.202    4.850    4.850 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000    4.850    4.850 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.276    0.276    5.125    5.125 <string>:1(<module>)
#         1    0.000    0.000    5.125    5.125 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  8388608  k =  3524149
#          31 function calls (6 primitive calls) in 12.896 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      26/1   12.244    0.471   12.244   12.244 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000   12.244   12.244 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    0.653    0.653   12.896   12.896 <string>:1(<module>)
#         1    0.000    0.000   12.896   12.896 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  16777216  k =  3222819
#          38 function calls (6 primitive calls) in 23.443 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      33/1   22.068    0.669   22.068   22.068 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000   22.068   22.068 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    1.375    1.375   23.443   23.443 <string>:1(<module>)
#         1    0.000    0.000   23.443   23.443 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  33554432  k =  5594286
#          31 function calls (6 primitive calls) in 50.873 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      26/1   47.915    1.843   47.915   47.915 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000   47.915   47.915 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    2.957    2.957   50.873   50.873 <string>:1(<module>)
#         1    0.000    0.000   50.873   50.873 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  67108864  k =  28322091
#          40 function calls (6 primitive calls) in 142.467 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      35/1  135.982    3.885  135.982  135.982 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000  135.982  135.982 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1    6.485    6.485  142.466  142.466 <string>:1(<module>)
#         1    0.000    0.000  142.467  142.467 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Kich thuoc mang dang la  134217728  k =  117343070
#          48 function calls (6 primitive calls) in 264.649 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      43/1  248.178    5.772  248.178  248.178 <ipython-input-1-0d89ae672e18>:1(QuickSelect)
#         1    0.000    0.000  248.178  248.178 <ipython-input-1-0d89ae672e18>:21(kth_element_qs_Quang)
#         1   16.470   16.470  264.648  264.648 <string>:1(<module>)
#         1    0.000    0.000  264.649  264.649 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
