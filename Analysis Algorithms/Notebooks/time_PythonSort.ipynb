# %%
def QuickSelect(left, right, a, k):
  if (left == right):
    return a[left]
 
  #index = Partition(a, left, right)
  if(left < right):
    index = left -1
    for j in range(left, right):
      if (a[j] >= a[right]):
        index += 1
        a[index], a[j] = a[j], a[index]
 
    a[index + 1], a[right] = a[right], a[index + 1]
    index += 1
 
    if (k == index):
      return a[k]
    if (k < index):
      return QuickSelect(left, index-1, a, k)
    return QuickSelect(index+1, right, a, k)  
def kth_element_qs_Quang(arr, k):
  return QuickSelect(0,len(arr)-1,arr, k-1)

# %%
def kth_element_sort(arr, k):
  arr.sort()
  return arr[len(arr)-k]

# %%
for j in range(1, 40):
  a=[i for i in range(2**j)]
  import random
  random.shuffle(a)
  k = random.randint(0, len(a)-1)
  #print(a[:])
  import cProfile
  print("Kich thuoc mang dang la ", len(a), " k = ", k)
  cProfile.run("kth_element_sort(a[:], k)")
  #print(a[:])
  #cProfile.run("kth_element_qs_Quang(a[:], k)")
# Out:
# Kich thuoc mang dang la  2  k =  1
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  4  k =  3
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  8  k =  4
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  16  k =  14
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  32  k =  26
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  64  k =  15
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  128  k =  90
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  256  k =  79
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  512  k =  141
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  1024  k =  877
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  2048  k =  2037
#          6 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  4096  k =  3244
#          6 function calls in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.001    0.001    0.001    0.001 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  8192  k =  4161
#          6 function calls in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.001    0.001    0.001    0.001 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  16384  k =  16000
#          6 function calls in 0.003 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.000    0.000    0.003    0.003 <string>:1(<module>)
#         1    0.000    0.000    0.003    0.003 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.003    0.003    0.003    0.003 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  32768  k =  8576
#          6 function calls in 0.007 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.001    0.001    0.007    0.007 <string>:1(<module>)
#         1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.006    0.006    0.006    0.006 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  65536  k =  6237
#          6 function calls in 0.031 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.016    0.016 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.015    0.015    0.031    0.031 <string>:1(<module>)
#         1    0.000    0.000    0.031    0.031 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.014    0.014    0.014    0.014 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  131072  k =  35588
#          6 function calls in 0.035 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.033    0.033 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.002    0.002    0.035    0.035 <string>:1(<module>)
#         1    0.000    0.000    0.035    0.035 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.032    0.032    0.032    0.032 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  262144  k =  84415
#          6 function calls in 0.092 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.085    0.085 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.007    0.007    0.092    0.092 <string>:1(<module>)
#         1    0.000    0.000    0.092    0.092 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.083    0.083    0.083    0.083 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  524288  k =  242936
#          6 function calls in 0.193 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.180    0.180 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.013    0.013    0.193    0.193 <string>:1(<module>)
#         1    0.000    0.000    0.193    0.193 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.180    0.180    0.180    0.180 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  1048576  k =  267820
#          6 function calls in 0.551 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.517    0.517 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.034    0.034    0.551    0.551 <string>:1(<module>)
#         1    0.000    0.000    0.551    0.551 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.515    0.515    0.515    0.515 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  2097152  k =  1087445
#          6 function calls in 1.057 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.981    0.981 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.076    0.076    1.057    1.057 <string>:1(<module>)
#         1    0.000    0.000    1.057    1.057 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.981    0.981    0.981    0.981 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  4194304  k =  3844777
#          6 function calls in 2.308 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    2.110    2.110 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.198    0.198    2.308    2.308 <string>:1(<module>)
#         1    0.000    0.000    2.308    2.308 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    2.109    2.109    2.109    2.109 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  8388608  k =  2270240
#          6 function calls in 5.189 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    4.693    4.693 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    0.496    0.496    5.189    5.189 <string>:1(<module>)
#         1    0.000    0.000    5.189    5.189 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    4.692    4.692    4.692    4.692 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  16777216  k =  1577454
#          6 function calls in 11.141 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001   10.079   10.079 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    1.062    1.062   11.141   11.141 <string>:1(<module>)
#         1    0.000    0.000   11.141   11.141 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1   10.078   10.078   10.078   10.078 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  33554432  k =  26116244
#          6 function calls in 24.964 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.006    0.006   22.728   22.728 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    2.235    2.235   24.964   24.964 <string>:1(<module>)
#         1    0.000    0.000   24.964   24.964 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1   22.722   22.722   22.722   22.722 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  67108864  k =  48698806
#          6 function calls in 54.786 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   50.099   50.099 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1    4.687    4.687   54.786   54.786 <string>:1(<module>)
#         1    0.000    0.000   54.786   54.786 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1   50.097   50.097   50.097   50.097 {method 'sort' of 'list' objects}
#
#
# Kich thuoc mang dang la  134217728  k =  57746410
#          6 function calls in 123.809 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  112.575  112.575 <ipython-input-3-81afe2e77a6a>:1(kth_element_sort)
#         1   11.234   11.234  123.809  123.809 <string>:1(<module>)
#         1    0.000    0.000  123.809  123.809 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1  112.575  112.575  112.575  112.575 {method 'sort' of 'list' objects}

# %%
for j in range(1, 40):
  a=[i for i in range(2**j)]
  import random
  random.shuffle(a)
  k = random.randint(0, len(a)-1)
  #print(a[:])
  import cProfile
  print("Kich thuoc mang dang la ", len(a), " k = ", k)
  #cProfile.run("kth_element_sort(a[:], k)")
  #print(a[:])
  cProfile.run("kth_element_qs_Quang(a[:], k)")
